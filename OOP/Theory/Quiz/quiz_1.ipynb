# %% [markdown]
# # Quiz to test OOP Knowledge

# %% [markdown]
# # A Local Variable:
#
#  a) Can be used anywhere in the program
#  b) Is declared within a method
#  c) Has to accept a class

# %% [markdown]
# # Defining 2 methods with the same name but with different parameters is called:
#
#  a) Loading
#  b) Overloading
#  c) Multiplexing

# %% [markdown]
# # Polymorphism occurs when the child class methods:
#
#  a) Override the parent class methods but maintain the implementation
#  b) Maintain the same return value and arguments, but are implemented differently
#  c) Have different return value and arguments than the parent class

# %% [markdown]
# # If an attribute is private, which methods have access to it?
#
#  a) Only those defined in the same class
#  b) Only static methods in the same class
#  c) Only instance methods in the same class

# %% [markdown]
# # The concept of "derived class" means it's related to:
#
#  a) Encapsulation
#  b) Data hiding
#  c) Abstract data types

# %% [markdown]
# # Inheritance is a way of:
#
#  a) Organizing data
#  b) Passing arguments to class objects
#  c) Adding features to existing classes without rewriting them

# %% [markdown]
# # What concept allows class details to not be visible to other classes or objects?
#
#  a) Encapsulation
#  b) Inheritance
#  c) Polymorphism

# %% [markdown]
# #  Which concept lets you extract only necessary information from an object, hiding technical details?
#
#  a) Encapsulation
#  b) Inheritance
#  c) Abstraction
